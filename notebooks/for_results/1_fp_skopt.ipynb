# %% [markdown]
# # Fixed policy optimization visuals

# %%
from skopt import load
from skopt.plots import plot_objective
from huggingface_hub import hf_hub_download

# %% [markdown]
# ## Load

# %%
cr_UM1_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/cr-UM1-noise0.2.pkl")
cr_UM2_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/cr-UM2-noise0.2.pkl")
cr_UM3_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/cr-UM3-noise0.2.pkl")

esc_UM1_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/esc-UM1-noise0.2.pkl")
esc_UM2_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/esc-UM2-noise0.2.pkl")
esc_UM3_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/esc-UM3-noise0.2.pkl")

msy_UM1_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/msy-UM1-noise0.2.pkl")
msy_UM2_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/msy-UM2-noise0.2.pkl")
msy_UM3_file = hf_hub_download(repo_id="boettiger-lab/rl4eco", filename="sb3/rl4fisheries/results/msy-UM3-noise0.2.pkl")
# Out:
# cr-UM1-noise0.2.pkl:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# cr-UM2-noise0.2.pkl:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# cr-UM3-noise0.2.pkl:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# esc-UM1-noise0.2.pkl:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# esc-UM2-noise0.2.pkl:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# esc-UM3-noise0.2.pkl:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# msy-UM1-noise0.2.pkl:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# msy-UM2-noise0.2.pkl:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# msy-UM3-noise0.2.pkl:   0%|          | 0.00/2.14M [00:00<?, ?B/s]

# %%
cr_UM1 = load(cr_UM1_file)
cr_UM2 = load(cr_UM2_file)
cr_UM3 = load(cr_UM3_file)

esc_UM1 = load(esc_UM1_file)
esc_UM2 = load(esc_UM2_file)
esc_UM3 = load(esc_UM3_file)

msy_UM1 = load(msy_UM1_file)
msy_UM2 = load(msy_UM2_file)
msy_UM3 = load(msy_UM3_file)

# %% [markdown]
# ## Results

# %%
print(cr_UM1.x, cr_UM1.fun)
print(esc_UM1.x, esc_UM1.fun)
print(msy_UM1.x, msy_UM1.fun)
print(" ")
print(cr_UM2.x, cr_UM2.fun)
print(esc_UM2.x, esc_UM2.fun)
print(msy_UM2.x, msy_UM2.fun)
print(" ")
print(cr_UM3.x, cr_UM3.fun)
print(esc_UM3.x, esc_UM3.fun)
print(msy_UM3.x, msy_UM3.fun)
# Out:
# [3.081701770400932, 0.2922662802699992, 0.8] -104.20831191391314
# [1.0374930375809375] -105.01364562295369
# [0.06605772875366243] -74.32775628874901
#
# [0.07158710228635687, 1e-05, 0.0781138994177048] -176.6966996474175
# [0.8361029371481715] -118.45176398731545
# [0.057272769107196704] -179.0755292786719
#
# [0.3805753198405787, 0.6597879762048932, 0.07646903299678874] -39.23350498183124
# [1.2894637279268146] -27.933008655085573
# [0.057848682709077684] -36.28302394224736

# %%
(
    plot_objective(cr_UM1, size = 4),
    plot_objective(cr_UM2, size = 4),
    plot_objective(cr_UM3, size = 4),
)
# Out:
# (<Axes: >, <Axes: >, <Axes: >)

# %%
# (
#     plot_objective(esc_UM1, size = 4),
#     plot_objective(esc_UM2, size = 4),
#     plot_objective(esc_UM3, size = 4),
# )

# %%
(
    plot_objective(msy_UM1, size = 4),
    plot_objective(msy_UM2, size = 4),
    plot_objective(msy_UM3, size = 4),
)
# Out:
# (<Axes: >, <Axes: >, <Axes: >)
