# %% [markdown]
# # Spasmodic recruitment stochasticity

# %%
from rl4fisheries.envs.asm_fns import get_r_devs_v2, get_r_devs

# %%
import pandas as pd

# %%
N_YEAR = 1_000

r_v1 = pd.DataFrame({
    'dev': get_r_devs(n_year=N_YEAR)
})
r_v2 = pd.DataFrame({
    'dev': get_r_devs_v2(n_year=N_YEAR)
})

# %%
r_v1.plot(logy=True)
# Out:
# <Axes: >

# %%
r_v2.plot(logy=True)
# Out:
# <Axes: >

# %%
r_v1.plot(kind='hist', logy=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
r_v2.plot(kind='hist', logy=True)
# Out:
# <Axes: ylabel='Frequency'>
